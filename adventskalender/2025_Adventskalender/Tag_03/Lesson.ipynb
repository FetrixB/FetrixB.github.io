# %% [markdown]
# # 🎄 Tag 03: Das Elf-Inventar System 📦
#
# ## 🦌 Minecraft-Weihnachtsgeschichte
#
# Hallo Felix! 🎮
#
# Heute betrittst du das geheime **Elfen-Warenlager** tief unter dem Weihnachtsbaum. Der Elfen-Lagermeister **Pixelbert** (also der Chef über alle Regale) ist völlig verzweifelt – sein magisches Inventarsystem ist durcheinandergeraten!
#
# Die uralte **Pixel-Schatzkiste** mit ihren 64 Slots ist zwar noch da, aber die Items sind wild durcheinander und reagieren nicht mehr richtig auf Berührungen. Pixelbert flüstert dir, dass niemand mehr weiß, in welchem Fach welches Geschenk steckt.
#
# *"Hilf uns, Felix!"* ruft Pixelbert. *"Ohne ein funktionierendes Inventar können wir die Weihnachtsgeschenke nicht organisieren! Du musst unsere **Grid-Magie** wiederherstellen, damit jedes Geschenk sein Plätzchen findet!"*
#
# Du erkennst schnell: Das ist ein perfekter Fall für **HTML-Listen** und **CSS Grid**! Stell dir HTML wie die nummerierte Liste der Fächer vor und CSS Grid wie das karierten Heftblatt, das alles ordentlich ausrichtet. 💡
#
# ---
#
# ## 🎯 Das lernst du heute
#
# **WOW-Ziel:** Ein echtes Minecraft-Inventar mit 64 Slots und beeindruckenden Hover-Effekten! ⚡
#
# ### 🧱 HTML-Listen als Datenstrukturen
# - **Warum Listen?** In Minecraft ist jedes Inventar eigentlich eine **Liste von Items**
# - `<ul>` = Deine Inventar-Container (wie eine Kiste)
# - `<li>` = Einzelne Slots (wie die Fächer in der Kiste)
# - **Gut verständlich für Menschen & Technik:** Screen-Reader verstehen "das ist eine Liste von Items"
#
# ### 🏗️ CSS Grid für 2D-Layouts
# - **8x8 = 64 Slots** - genau wie in Minecraft!
# - `grid-template-columns: repeat(8, 1fr)` = 8 gleichmäßige Spalten
# - `gap` für perfekte Abstände zwischen Items
# - **Zweidimensional = Koordinaten:** Du siehst Reihen und Spalten gleichzeitig (wie ein Schachbrett)
#
# ### ✨ Hover-Animationen & Pixel-Art
# - `:hover` Pseudo-Klassen für Interaktivität
# - `transform: scale()` + `rotate()` für coole Effekte
# - `image-rendering: pixelated` für scharfe Minecraft-Kanten
#
# **Das Coole:** Nach heute kannst du **jedes Grid-Layout** erstellen - von Inventaren bis zu Foto-Galerien! 🌟

# %% [markdown]
# ## 💎 Verstehen & Ausprobieren
#
# Lass uns die **drei Kernkonzepte** von heute verstehen und mit interaktiven Beispielen experimentieren! Stell dir vor, wir testen zuerst kleine Prototypen, bevor wir die große Pixel-Kiste reparieren.

# %%
# 🧱 KONZEPT 1: HTML-Listen als Datenstrukturen
from IPython.core.display import HTML

# Verstehe Listen-Struktur mit einem Mini-Inventar
demo_html = '''
<div style="font-family: 'Courier New', monospace; background: #1a1a2e; color: white; padding: 20px; border-radius: 10px;">
    <h3 style="color: #16a34a; margin-top: 0;">🧱 HTML-Liste = Inventar-Container</h3>
    
    <!-- Ungeordnete Liste = Inventar -->
    <ul style="
        list-style: none; 
        padding: 0; 
        display: grid; 
        grid-template-columns: repeat(4, 60px); 
        gap: 5px;
        background: #2d2d2d;
        padding: 10px;
        border-radius: 5px;
    ">
        <!-- List Items = Inventar-Slots -->
        <li style="
            width: 60px; height: 60px; 
            background: linear-gradient(135deg, #404040, #2a2a2a);
            border: 2px solid #555;
            display: flex; 
            align-items: center; 
            justify-content: center;
            font-size: 24px;
            border-radius: 4px;
            transition: transform 0.3s ease;
        " onmouseover="this.style.transform='scale(1.1)'" onmouseout="this.style.transform='scale(1)'">⚔️</li>
        
        <li style="
            width: 60px; height: 60px; 
            background: linear-gradient(135deg, #404040, #2a2a2a);
            border: 2px solid #555;
            display: flex; 
            align-items: center; 
            justify-content: center;
            font-size: 24px;
            border-radius: 4px;
            transition: transform 0.3s ease;
        " onmouseover="this.style.transform='scale(1.1)'" onmouseout="this.style.transform='scale(1)'">🎄</li>
        
        <li style="
            width: 60px; height: 60px; 
            background: linear-gradient(135deg, #404040, #2a2a2a);
            border: 2px solid #555;
            display: flex; 
            align-items: center; 
            justify-content: center;
            font-size: 24px;
            border-radius: 4px;
            transition: transform 0.3s ease;
        " onmouseover="this.style.transform='scale(1.1)'" onmouseout="this.style.transform='scale(1)'">🍭</li>
        
        <li style="
            width: 60px; height: 60px; 
            background: linear-gradient(135deg, #1a1a1a, #0f0f0f);
            border: 2px solid #333;
            display: flex; 
            align-items: center; 
            justify-content: center;
            font-size: 16px;
            color: #666;
            border-radius: 4px;
        ">📦</li>

        <li style="
            width: 60px; height: 60px; 
            background: linear-gradient(135deg, #1a1a1a, #0f0f0f);
            border: 2px solid #333;
            display: flex; 
            align-items: center; 
            justify-content: center;
            font-size: 16px;
            color: #666;
            border-radius: 4px;
        ">📦</li>

        <li style="
            width: 60px; height: 60px; 
            background: linear-gradient(135deg, #404040, #2a2a2a);
            border: 2px solid #555;
            display: flex; 
            align-items: center; 
            justify-content: center;
            font-size: 24px;
            border-radius: 4px;
            transition: transform 0.3s ease;
        " onmouseover="this.style.transform='scale(1.1)'" onmouseout="this.style.transform='scale(1)'">🐘💨</li>
    </ul>
    
    <p style="color: #9ca3af; font-size: 14px; margin-top: 15px;">
        ☝️ <strong>Schwebe über die Items!</strong> Siehst du? Jedes &lt;li&gt; ist ein Slot!
    </p>
    
    <div style="background: #16a34a; padding: 10px; border-radius: 5px; margin-top: 15px;">
        <strong>💡 Warum Listen verwenden?</strong><br>
        ✅ Semantisch korrekt (Screen-Reader: "Liste mit 4 Items")<br>
        ✅ Einfach erweiterbar (neue &lt;li&gt; hinzufügen)<br>
        ✅ CSS Grid funktioniert perfekt mit Listen<br>
        ✅ JavaScript kann einfach Items manipulieren
    </div>
</div>
'''

HTML(demo_html)
# Out:
# <div style="font-family: 'Courier New', monospace; background: #1a1a2e; color: white; padding: 20px; border-radius: 10px;">
#     <h3 style="color: #16a34a; margin-top: 0;">🧱 HTML-Liste = Inventar-Container</h3>
#
#     <!-- Ungeordnete Liste = Inventar -->
#     <ul style="
#         list-style: none;
#         padding: 0;
#         display: grid;
#         grid-template-columns: repeat(4, 60px);
#         gap: 5px;
#         background: #2d2d2d;
#         padding: 10px;
#         border-radius: 5px;
#     ">
#         <!-- List Items = Inventar-Slots -->
#         <li style="
#             width: 60px; height: 60px;
#             background: linear-gradient(135deg, #404040, #2a2a2a);
#             border: 2px solid #555;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-size: 24px;
#             border-radius: 4px;
#             transition: transform 0.3s ease;
# ...

# %%
# 🏗️ KONZEPT 2: CSS Grid für 2D-Layouts
from IPython.core.display import HTML

# CSS Grid Eigenschaften verstehen
grid_demo_html = '''
<div style="font-family: 'Courier New', monospace; background: #1a1a2e; color: white; padding: 20px; border-radius: 10px;">
    <h3 style="color: #ca8a04; margin-top: 0;">🏗️ CSS Grid = 2D-Layout-System</h3>
    
    <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
        <!-- Grid-Beispiel 1: 2x2 -->
        <div>
            <h4 style="color: #3b82f6;">📐 2x2 Grid (4 Slots)</h4>
            <div style="
                display: grid;
                grid-template-columns: repeat(2, 50px);
                grid-template-rows: repeat(2, 50px);
                gap: 30px;
                background: #2d2d2d;
                padding: 10px;
                border-radius: 5px;
                width: fit-content;
            ">
                <div style="background: #4ade80; border-radius: 3px; display: flex; align-items: center; justify-content: center;">1</div>
                <div style="background: #4ade80; border-radius: 3px; display: flex; align-items: center; justify-content: center;">2</div>
                <div style="background: #4ade80; border-radius: 3px; display: flex; align-items: center; justify-content: center;">3</div>
                <div style="background: #4ade80; border-radius: 3px; display: flex; align-items: center; justify-content: center;">4</div>
            </div>
            <code style="font-size: 12px; color: #9ca3af;">
                grid-template-columns: repeat(2, 50px);<br>
                grid-template-rows: repeat(2, 50px);
            </code>
        </div>
        
        <!-- Grid-Beispiel 2: 4x2 -->
        <div>
            <h4 style="color: #a855f7;">📐 4x4 Grid (16 Slots)</h4>
            <div style="
                display: grid;
                grid-template-columns: repeat(4, 30px);
                grid-template-rows: repeat(4, 30px);
                gap: 2px;
                background: #2d2d2d;
                padding: 10px;
                border-radius: 5px;
                width: fit-content;
            ">
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">1</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">2</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">3</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">4</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">5</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">6</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">7</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">8</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">9</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">10</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">11</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">12</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">13</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">14</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">15</div>
                <div style="background: #a855f7; border-radius: 2px; font-size: 12px; display: flex; align-items: center; justify-content: center;">16</div>
            </div>
            <code style="font-size: 12px; color: #9ca3af;">
                grid-template-columns: repeat(4, 30px);<br>
                grid-template-rows: repeat(2, 30px);
            </code>
        </div>
    </div>
    
    <div style="background: #ca8a04; padding: 15px; border-radius: 8px; margin-top: 20px;">
        <strong>🎯 Minecraft-Inventar = 8x8 Grid = 64 Slots!</strong><br><br>
        <code style="background: rgba(0,0,0,0.3); padding: 5px; border-radius: 3px; display: inline-block;">
            grid-template-columns: repeat(8, 1fr);<br>
            grid-template-rows: repeat(8, 1fr);
        </code><br><br>
        <strong>1fr</strong> = "1 Fraction" = Gleich große Teile des verfügbaren Platzes
    </div>
    
    <div style="background: #dc2626; padding: 10px; border-radius: 5px; margin-top: 15px;">
        <strong>⚡ Grid vs. Flexbox:</strong><br>
        📦 <strong>Flexbox</strong> = 1D (nur Reihe ODER Spalte)<br>
        🏗️ <strong>Grid</strong> = 2D (Reihen UND Spalten gleichzeitig)
    </div>
</div>
'''

HTML(grid_demo_html)
# Out:
# <div style="font-family: 'Courier New', monospace; background: #1a1a2e; color: white; padding: 20px; border-radius: 10px;">
#     <h3 style="color: #ca8a04; margin-top: 0;">🏗️ CSS Grid = 2D-Layout-System</h3>
#
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <!-- Grid-Beispiel 1: 2x2 -->
#         <div>
#             <h4 style="color: #3b82f6;">📐 2x2 Grid (4 Slots)</h4>
#             <div style="
#                 display: grid;
#                 grid-template-columns: repeat(2, 50px);
#                 grid-template-rows: repeat(2, 50px);
#                 gap: 30px;
#                 background: #2d2d2d;
#                 padding: 10px;
#                 border-radius: 5px;
#                 width: fit-content;
#             ">
#                 <div style="background: #4ade80; border-radius: 3px; display: flex; align-items: center; justify-content: center;">1</div>
# ...

# %%
# ✨ KONZEPT 3: Hover-Animationen & Pixel-Art
from IPython.core.display import HTML

# Hover-Effekte und Pixel-Art verstehen
hover_demo_html = '''
<div style="font-family: 'Courier New', monospace; background: #1a1a2e; color: white; padding: 20px; border-radius: 10px;">
    <h3 style="color: #dc2626; margin-top: 0;">✨ Hover-Magie für Interaktivität</h3>
    
    <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
        <!-- Hover-Beispiele -->
        <div>
            <h4 style="color: #16a34a;">🎮 Verschiedene Hover-Effekte</h4>
            <div style="display: grid; grid-template-columns: repeat(3, 60px); gap: 10px;">
                <!-- Scale-Effekt -->
                <div style="
                    width: 60px; height: 60px; 
                    background: linear-gradient(135deg, #dc2626, #991b1b);
                    border: 2px solid #555;
                    display: flex; align-items: center; justify-content: center;
                    font-size: 24px; border-radius: 6px;
                    transition: transform 0.3s ease;
                    cursor: pointer;
                " 
                onmouseover="this.style.transform='scale(5)'" 
                onmouseout="this.style.transform='scale(1)'">🔥</div>
                
                <!-- Rotate-Effekt -->
                <div style="
                    width: 60px; height: 60px; 
                    background: linear-gradient(135deg, #3b82f6, #1d4ed8);
                    border: 2px solid #555;
                    display: flex; align-items: center; justify-content: center;
                    font-size: 24px; border-radius: 6px;
                    transition: transform 0.3s ease;
                    cursor: pointer;
                " 
                onmouseover="this.style.transform='rotate(360deg)'" 
                onmouseout="this.style.transform='rotate(0deg)'">❄️</div>
                
                <!-- Kombiniert -->
                <div style="
                    width: 60px; height: 60px; 
                    background: linear-gradient(135deg, #ca8a04, #92400e);
                    border: 2px solid #555;
                    display: flex; align-items: center; justify-content: center;
                    font-size: 24px; border-radius: 6px;
                    transition: all 0.3s ease;
                    cursor: pointer;
                " 
                onmouseover="this.style.transform='scale(3) rotate(180deg)'; this.style.boxShadow='0 0 20px rgba(202, 138, 4, 0.8)';" 
                onmouseout="this.style.transform='scale(1) rotate(0deg)'; this.style.boxShadow='none';">⭐</div>
            </div>
            <p style="font-size: 12px; color: #9ca3af; margin-top: 10px;">
                🔥 Scale &nbsp;&nbsp; ❄️ Rotate &nbsp;&nbsp; ⭐ Kombiniert + Glow
            </p>
        </div>
        <div>
            <h4 style="color: #16a34a;">🎮 Verschiedene Hover-Effekte</h4>
            <div style="display: grid; grid-template-columns: repeat(3, 60px); gap: 10px;">
                <!-- Scale-Effekt -->
                <div style="
                    width: 60px; height: 60px; 
                    background: linear-gradient(135deg, #dc2626, #991b1b);
                    border: 2px solid #555;
                    display: flex; align-items: center; justify-content: center;
                    font-size: 24px; border-radius: 6px;
                    transition: transform 0.3s ease;
                    cursor: pointer;
                " 
                onmouseover="this.style.transform='scale(1.2)'" 
                onmouseout="this.style.transform='scale(1)'">🔥</div>
                
                <!-- Rotate-Effekt -->
                <div style="
                    width: 60px; height: 60px; 
                    background: linear-gradient(135deg, #3b82f6, #1d4ed8);
                    border: 2px solid #555;
                    display: flex; align-items: center; justify-content: center;
                    font-size: 24px; border-radius: 6px;
                    transition: transform 0.3s ease;
                    cursor: pointer;
                " 
                onmouseover="this.style.transform='rotate(15deg)'" 
                onmouseout="this.style.transform='rotate(0deg)'">❄️</div>
                
                <!-- Kombiniert -->
                <div style="
                    width: 60px; height: 60px; 
                    background: linear-gradient(135deg, #ca8a04, #92400e);
                    border: 2px solid #555;
                    display: flex; align-items: center; justify-content: center;
                    font-size: 24px; border-radius: 6px;
                    transition: all 0.3s ease;
                    cursor: pointer;
                " 
                onmouseover="this.style.transform='scale(1.2) rotate(15deg)'; this.style.boxShadow='0 0 20px rgba(202, 138, 4, 0.8)';" 
                onmouseout="this.style.transform='scale(1) rotate(0deg)'; this.style.boxShadow='none';">⭐</div>
            </div>
            <div style="
                    width: 60px; height: 60px; 
                    background: linear-gradient(135deg, #3b82f6, #1d4ed8);
                    border: 2px solid #555;
                    display: flex; align-items: center; justify-content: center;
                    font-size: 24px; border-radius: 6px;
                    transition: transform 0.3s ease;
                    cursor: pointer;
                " 
                onmouseover="this.style.transform='move(15px)'" 
                onmouseout="this.style.transform='move(0px)'">🐘</div>
                
            <p style="font-size: 12px; color: #9ca3af; margin-top: 10px;">
                🔥 Scale &nbsp;&nbsp; ❄️ Rotate &nbsp;&nbsp; ⭐ Kombiniert + Glow
            </p>
        </div>
        
        <!-- Pixel-Art Info -->
        <div>
            <h4 style="color: #a855f7;">🎨 Minecraft Pixel-Art Style</h4>
            <div style="
                width: 120px; height: 120px; 
                background: 
                    linear-gradient(0deg, transparent 0%, transparent 24%, #8B4513 25%, #8B4513 49%, transparent 50%, transparent 74%, #A86134 75%, #A86134 100%),
                    linear-gradient(90deg, transparent 0%, transparent 24%, #8B4513 25%, #8B4513 49%, transparent 50%, transparent 74%, #CD853F 75%, #CD853F 100%);
                background-size: 20px 20px;
                image-rendering: pixelated;
                border: 3px solid #8b4513;
                margin: 0 auto 15px;
                border-radius: 8px;
            "></div>
            <code style="font-size: 11px; color: #16a34a; display: block; text-align: center;">
                image-rendering: pixelated;<br>
                🎯 Scharfe Minecraft-Kanten!
            </code>
        </div>
    </div>
    
    <div style="background: #dc2626; padding: 15px; border-radius: 8px; margin-top: 20px;">
        <strong>💻 CSS-Code für Hover-Effekte:</strong><br><br>
        <code style="background: rgba(0,0,0,0.3); padding: 10px; border-radius: 5px; display: block;">
.inventory-slot:hover {<br>
&nbsp;&nbsp;transform: scale(1.1) rotate(2deg);<br>
&nbsp;&nbsp;box-shadow: 0 0 20px rgba(74, 222, 128, 0.5);<br>
&nbsp;&nbsp;border-color: #4ade80;<br>
}<br><br>
/* Pixel-Art für scharfe Kanten */<br>
img, .pixel-art {<br>
&nbsp;&nbsp;image-rendering: pixelated;<br>
}
        </code>
    </div>
    
    <p style="color: #9ca3af; font-size: 14px; margin-top: 15px;">
        💡 <strong>Tipp:</strong> Kombiniere mehrere transform-Eigenschaften für noch coolere Effekte!
    </p>
</div>
'''

HTML(hover_demo_html)
# Out:
# <div style="font-family: 'Courier New', monospace; background: #1a1a2e; color: white; padding: 20px; border-radius: 10px;">
#     <h3 style="color: #dc2626; margin-top: 0;">✨ Hover-Magie für Interaktivität</h3>
#
#     <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px;">
#         <!-- Hover-Beispiele -->
#         <div>
#             <h4 style="color: #16a34a;">🎮 Verschiedene Hover-Effekte</h4>
#             <div style="display: grid; grid-template-columns: repeat(3, 60px); gap: 10px;">
#                 <!-- Scale-Effekt -->
#                 <div style="
#                     width: 60px; height: 60px;
#                     background: linear-gradient(135deg, #dc2626, #991b1b);
#                     border: 2px solid #555;
#                     display: flex; align-items: center; justify-content: center;
#                     font-size: 24px; border-radius: 6px;
#                     transition: transform 0.3s ease;
#                     cursor: pointer;
# ...

# %% [markdown]
# ## 🎯 Deine Aufgabe - Die 3 TODOs
#
# Pixelbert braucht deine Hilfe! Das Inventar-System funktioniert zu 80%, aber **3 wichtige Teile** fehlen noch:
#
# ### 📋 TODO-Übersicht
#
# 1. **🧱 HTML-TODO:** Vervollständige das 8x8 Grid *(5 Minuten)*
# 2. **🎨 CSS-TODO:** Aktiviere die Hover-Animationen *(5 Minuten)*
# 3. **⚡ JS-TODO:** Starte die Inventar-Initialisierung *(5 Minuten)*
#
# ---
#
# ### 🧱 TODO 1: HTML - Grid vervollständigen
#
# **📁 Datei:** `Aufgabe/index.html`
# **📍 Zeile:** Suche nach `<!-- TODO 1:`
#
# **❓ Problem:** Das Inventar hat nur 24 Items, aber Minecraft braucht 64 Slots!
#
# **🧠 Mini-Erklärung:** Denk an acht Eierkartons nebeneinander: Erst wenn alle Kästen da sind, kann jemand jedes Fach befüllen. Genau so wartet das Script auf ein vollständiges Grid.
#
# **✅ Lösung:** Du musst keine neuen Slots manuell erstellen. Das JavaScript macht das automatisch, ABER das Grid muss richtig strukturiert sein.
#
# **💡 Hinweis:** Schaue dir die bestehende HTML-Struktur an. Jeder Slot ist ein `<li>` Element innerhalb der `<ul class="inventory-grid">`.
#
# ---
#
# ### 🎨 TODO 2: CSS - Hover-Animationen aktivieren
#
# **📁 Datei:** `Aufgabe/style.css`
# **📍 Zeile:** Suche nach `/* TODO 2:`
#
# **❓ Problem:** Die Hover-Effekte sind auskommentiert - Items reagieren nicht auf Mausberührung!
#
# **🧠 Mini-Erklärung:** Kommentare sind wie eine Pausetaste. Die Magie steckt schon im Code, aber erst ohne `/* */` darf sie loslegen.
#
# **✅ Lösung:** Entferne die `/* */` Kommentare um die Hover-CSS-Regeln.
#
# **💡 Hinweis:** Achte darauf, dass sowohl `.inventory-slot:hover` als auch die Icon- und Count-Hover-Effekte aktiviert werden.
#
# ---
#
# ### ⚡ TODO 3: JavaScript - Initialisierung starten
#
# **📁 Datei:** `Aufgabe/script.js`
# **📍 Zeile:** Suche nach `// TODO 3:`
#
# **❓ Problem:** Das Inventar bleibt bei 24 Slots, weil die Initialisierung nicht gestartet wird!
#
# **🧠 Mini-Erklärung:** Stell dir einen Startknopf vor. Das Programm wartet brav, bis der DOM fertig ist, aber niemand drückt den Knopf für `initializeInventory()` und `setupEventListeners()`.
#
# **✅ Lösung:** Entkommentiere die zwei Funktionsaufrufe in der DOMContentLoaded-Funktion.
#
# **💡 Hinweis:** Du musst `initializeInventory()` und `setupEventListeners()` aufrufen.
#
# ---
#
# ### 🏁 Erfolgskontrolle
#
# **Das siehst du, wenn alles funktioniert:**
# - ✅ Ein perfektes 8x8 Grid mit 64 Slots
# - ✅ Items vergrößern sich und glühen beim Drüberfahren
# - ✅ Tooltips zeigen Item-Informationen
# - ✅ Leere Slots sind als 📦 sichtbar
# - ✅ Statistiken unten zeigen "24/40" gefüllte/leere Slots
#
# **🎮 Extra-Test:** Klicke auf Items für Details-Popups!

# %% [markdown]
# ## 🌟 Erfolg & neue Möglichkeiten
#
# ### 🎉 Was du heute gemeistert hast
#
# **🧠 Konzepte verstanden:**
# - **HTML-Listen** als semantische Container für strukturierte Daten
# - **CSS Grid** für präzise 2D-Layouts (8x8 = 64 Slots)
# - **Hover-Interaktionen** mit `transform`, `scale()` und `rotate()`
# - **Pixel-Art Rendering** für authentische Minecraft-Optik
#
# **🛠️ Praktische Fähigkeiten:**
# - Grid-Systeme für beliebige Anordnungen erstellen
# - Interaktive Hover-Effekte implementieren
# - Listen semantisch korrekt strukturieren
# - Responsive Design mit CSS Grid
#
# ---
#
# ### 🚀 Was du jetzt alles bauen kannst
#
# **🎮 Gaming UIs:**
# - Inventar-Systeme für Webspiele
# - Kartenspiel-Layouts (Poker, Magic)
# - Schachbrett oder Tic-Tac-Toe
# - RPG-Charakterbögen mit Grid-Slots
#
# **📸 Content-Layouts:**
# - Instagram-ähnliche Foto-Galerien
# - Portfolio-Grids für Designer
# - Produkt-Kataloge für Online-Shops
# - Dashboard-Layouts mit Widgets
#
# **🎨 Design-Patterns:**
# - Karten-basierte Interfaces (Material Design)
# - Tile-basierte Navigation
# - Responsive Icon-Grids
# - Data-Visualization-Grids
#
# ---
#
# ### 💡 Vertiefungs-Richtungen
#
# **🔥 Nächste Schritte:**
# - **CSS Grid Areas:** Benannte Bereiche für komplexe Layouts
# - **CSS Transforms:** 3D-Effekte und Perspektive
# - **JavaScript Events:** Drag & Drop für Items
# - **CSS Animations:** Keyframe-basierte Bewegungen
#
# **🎯 Projekt-Ideen:**
# - Erweitere das Inventar um **Drag & Drop**
# - Füge **Item-Kategorien** mit Farbkodierung hinzu
# - Implementiere **Sortier-Funktionen** (nach Wert, Name, etc.)
# - Erstelle ein **Crafting-System** mit Grid-Kombinationen
#
# ---
#
# ### 🎄 Weihnachts-Bonus
#
# Du hast **Pixelberts Inventar-System** gerettet! Die Elfen können wieder ordentlich arbeiten und alle Weihnachtsgeschenke werden pünktlich fertig.
#
# **Dein Minecraft-Weihnachts-Rang:** 🎖️ **Grid-Meister**
#
# **Morgen wartet:** Noch mehr CSS-Magie mit **Animationen und Übergängen**! 🌟
#
# ---
#
# *Gut gemacht, Felix! Du beherrschst jetzt eines der mächtigsten Layout-Tools im Web. CSS Grid öffnet dir die Tür zu praktisch jedem 2D-Design, das du dir vorstellen kannst!* ⚡🎮
