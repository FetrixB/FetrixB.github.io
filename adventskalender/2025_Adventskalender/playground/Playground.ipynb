# %%
opencode run "You are an experienced frontend web developer for developing gorgeous games with TailwindCSS, Anime.js, Vanilla JS or Three.js. Use context7 MCP to get latest library documentation. Create a 2 player pong web game."
# Out:
# |  Todo     3 todos
# |  List     playground
# |  Todo     3 todos
# |  Write    playground/index.html
# |  Todo     2 todos
# |  Write    playground/main.js
# |  Read     playground/main.js
# |  Edit     playground/main.js
# |  Edit     playground/main.js
# |  Todo     1 todos
# |  Read     playground/index.html
#
# - Crafted a neon arcade layout with Tailwind, Space Grotesk, layered gradients, scoreboard, and control legend tied to the canvas and overlay banner in `index.html:1-59`.
# - Added full Vanilla JS game loop with paddle controls, physics, collision response, scoreboard updates, win handling, and stability tweaks (delta clamp, restart logic) in `main.js:1-176`.
#
# Tests not run (browser game – open `index.html` in a local server/tab to verify). Next: 1) Launch with `npx serve` or similar to confirm controls and pacing; 2) Adjust speeds/target score if you want faster or longer rallies.
