# %%
opencode run "Du bist ein erfahrener Programmierlehrer für Kinder. Helfe mir bei den TODOs in der index.html (ohne die Dateien zu verändern - bitte sage es mir nur). Antworte unbedingt auf Deutsch."
# Out:
# |  Read     adventskalender/2025_Adventskalender/Tag_06/Aufgabe/index.html
#
# In `index.html:115` steckt der einzige TODO. Du brauchst dort einen kompletten `<figure>`-Block, damit das Kapitel ein illustriertes Beispiel hat:
#
# - Direkt nach dem erklärenden Absatz fügst du `<figure class="float-right max-w-[180px] ml-6">` ein (die Klassen sind nur ein Vorschlag), damit das Bild rechts neben dem Text „schwebt“.
# - In die Figur kommt ein `<img src="pfad/zum/bild.jpg" alt="kurzer Beschreibungssatz">`, damit sowohl Turn.js als auch der Fallback wissen, welches Motiv gezeigt wird und Screenreader einen Text haben.
# - Unter das Bild gehört ein `<figcaption class="text-xs text-slate-300 mt-2">Der Titel oder eine knappe Erklärung zum Bild.</figcaption`, so können Leser das Bild einordnen.
# ...

# %%
opencode run "Du bist ein erfahrener Programmierlehrer für Kinder. Helfe mir bei den TODOs in der style.css (ohne die Dateien zu verändern - bitte sage es mir nur). Antworte unbedingt auf Deutsch."
# Out:
# |  Read     adventskalender/2025_Adventskalender/Tag_06/Aufgabe/style.css
#
# Du kannst das TODO in `style.css:97` so lösen:
#
# - Ergänze eine Regel `.page-card figure`, die `float: right;` bekommt, dazu eine feste Breite (z. B. `width: 45%;`), eine Mindesthöhe oder `aspect-ratio` (z. B. `aspect-ratio: 4 / 3;`) und einen Außenabstand nach links/unten (`margin: 0 0 1.25rem 1.5rem;`), damit der Text sauber herumfließt.
# - Sorge dafür, dass das Bild die Figur komplett ausfüllt, indem du `.page-card figure img` (oder das entsprechende Element) mit `display: block; width: 100%; height: 100%; object-fit: cover; border-radius: 0.75rem;` versiehst.
# - Optional kannst du dem `figure` ein `overflow: hidden;` geben, falls die abgerundeten Ecken auf das Bild wirken sollen, und `max-width: 50%;` einsetzen, damit es auf größeren Screens nicht zu breit wird.
# ...

# %%
opencode run "Du bist ein erfahrener Programmierlehrer für Kinder. Helfe mir bei den TODOs in der script.js (ohne die Dateien zu verändern - bitte sage es mir nur). Antworte unbedingt auf Deutsch."

# %%
opencide run "Du bist ein erfahrener Programmierlehrer für Kinder. Bitte helfe mir mit: ..."
