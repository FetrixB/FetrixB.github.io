# %% [markdown]
# # 🎄 Tag 05 – Schneemanns digitales Fundament
#
# Der Blizzard hat die Holzhütte des weisen Schneemanns zerlegt. In deiner Werkstatt baust du ihm nun eine sichere HTML-Hütte mit warmem CSS-Licht und cleveren Buttons, damit er wieder alle Dorfbewohner beraten kann.

# %% [markdown]
# ## 🎯 Deine Mission für heute
# - Baue mit `header`, `main` und `footer` ein klares Grundgerüst – wie Dach, Wohnraum und Boden deiner Schneehütte.
# - Plane gemütliche Container, die Inhalte festhalten wie Schneeblöcke, damit nichts verrutscht.
# - Gib den Buttons deutlich sichtbare Zustände, damit Kinder sofort merken, was gerade aktiv ist.
# - Nutze die Dateien in `Loesung/` als Spickzettel und `Aufgabe/` als sicheren Spielplatz.

# %% [markdown]
# ### 🏗️ Die wichtigsten HTML-Fundamente
# Stell dir die Seite wie ein kleines Haus vor, das für Kinder leicht zu erkunden ist.
#
# **`<header>`** – Dachbalken der Seite
#
# - Enthält Logo, Navigation und Introtext, also alles, was Gäste zuerst sehen.
# - In `Loesung/index.html` bekommst du einen Orbitron-Titel plus eine Navi-Liste als anschauliches Beispiel.
#
# ```html
# <header class="content-shell frost-card">
#   <nav aria-label="Seiten-Navigation">
#     <ul>
#       <li><a href="#blaupause">Blueprints</a></li>
#       ...
#     </ul>
#   </nav>
# </header>
# ```
#
# **`<main>`** – Warmer Hauptraum mit mehreren `section`-Blöcken, in denen die eigentliche Geschichte passiert.
#
# **`<footer>`** – Feuerstelle für Kontaktinfos, damit Kinder wissen, wo sie mehr Hilfe finden.

# %% [markdown]
# ### 🌐 Layout-Container & Flexbox-Orga
# Container sind wie unsichtbare Boxen, die Breite und Abstand ordnen, damit Kinder Inhalte schnell finden.
#
# ```css
# .content-shell {
#   width: min(1200px, 92vw);
#   margin-inline: auto;
#   padding: clamp(1.5rem, 1.5vw, 2.5rem);
# }
#
# .blueprint-grid {
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(240px, 1fr));
#   gap: 1.25rem;
# }
# ```
#
# So fühlen sich die Sektionen wie klar beschriftete Räume in einem Minecraft-Haus an und niemand verirrt sich.

# %% [markdown]
# ## ✨ Dein praktisches WOW-Ziel
# - ✅ Baue eine Hero-Sektion mit Status-Badge und dem Button `Schneesturm stoppen`, damit sofort klar ist, was zu tun ist.
# - ✅ Ergänze Blueprint-Karten plus Timeline, die jeden Bau-Schritt mit kurzen, kindgerechten Texten erklärt.
# - ✅ Richte ein Button-Labor mit `aria-pressed` ein, damit auch Screenreader-Kinderfeedback verstehen.
# - ✅ Wärm den Footer als Feuerstelle mit einem freundlichen Accessibility-Hinweis auf.
#
# **Das Ergebnis:** Eine frostige, aber stabile Mini-Seite, die auf jeden Klick sichtbar reagiert und neugierig macht.

# %% [markdown]
# # 🧪 Verstehen

# %% [markdown]
# ## 🔍 Semantische Schichten verstehen
# Jede Ebene deiner Seite erfüllt eine Aufgabe – genau wie Etagen in einem Baumhaus. In `Loesung/index.html` findest du dieses Grundgerüst:
#
# ```html
# <header class="frost-card">...</header>
# <main>
#   <section class="hero">...</section>
#   <section class="blueprint">...</section>
#   <section class="button-lab">...</section>
# </main>
# <footer class="content-shell footer">...</footer>
# ```
#
# Wenn du diese Schichten sauber trennst, können Screenreader-Kinder sofort erkennen, wann sie sich im Dachbereich, Hauptraum oder an der Feuerstelle befinden.

# %% [markdown]
# ## 🎨 Container = gleichmäßige Räume
# Mit `content-shell`, `frost-card` und `frost-panel` bestimmst du Breite, Hintergrund und Schatten – ähnlich wie bunte Kartons für Bastelmaterial.
#
# ```css
# .frost-card {
#   backdrop-filter: blur(18px);
#   border-bottom: 1px solid var(--border-glow);
# }
#
# .frost-panel ul {
#   list-style: none;
#   margin: 1rem 0 0;
#   padding: 0;
# }
# ```
#
# Flexbox im Header und Grid in der Blueprint-Sektion halten die Elemente flexibel wie modulare Bauklötze und verhindern Chaos.

# %% [markdown]
# ## ⚡ Buttons mit Persönlichkeit
# Die Buttons im Labor verbinden CSS und JavaScript, damit Kinder nicht nur klicken, sondern auch merken, was passiert:
#
# ```javascript
# const blueprintMessages = { foundation: { title: "Header-Dach" } };
#
# button.addEventListener("click", () => {
#   button.setAttribute("aria-pressed", "true");
#   updateOutput(button.dataset.blueprint);
# });
# ```
#
# `aria-pressed` verrät Screenreadern, welcher Button aktiv ist, und über `dataset` schiebst du den passenden Infotext wie eine kleine Sprechblase ins Ausgabefeld.

# %% [markdown]
# # 🧪 Ausprobieren
# Starte dieses Mini-Labor. Klick nacheinander auf die Buttons und lies laut vor, was sich ändert – so prüfst du direkt, ob Texte und Farben verständlich bleiben.

# %%
from IPython.core.display import HTML

demo_html = """
<!DOCTYPE html>
<html lang="de">
<head>
  <style>
    body { font-family: 'Inter', sans-serif; background:#020617; color:#f8fbff; }
    .demo-shell { max-width: 620px; margin: 0 auto; padding: 24px; border-radius: 24px; background: rgba(255,255,255,0.04); border:1px solid rgba(91,250,222,0.4); }
    .demo-buttons { display:flex; gap:12px; flex-wrap:wrap; }
    .demo-button { flex:1 1 160px; border:none; border-radius:999px; padding:12px 18px; font-weight:700; text-transform:uppercase; color:#020617; background:linear-gradient(135deg,#5bfade,#7bdff2); box-shadow:0 6px 0 rgba(11,61,99,0.9); cursor:pointer; transition:transform .2s, box-shadow .2s; }
    .demo-button.is-active { background:linear-gradient(135deg,#8b5cf6,#5bfade); color:#fff; }
    .demo-button:active { transform:translateY(3px); box-shadow:0 3px 0 rgba(11,61,99,0.9); }
    .demo-output { margin-top:20px; padding:16px; border-radius:16px; background:rgba(2,6,23,0.8); border:1px solid rgba(91,250,222,0.4); min-height:120px; }
    .demo-output h4 { margin:0 0 8px; font-family:'Orbitron',sans-serif; }
    .demo-output code { background:rgba(0,0,0,0.4); padding:3px 6px; border-radius:6px; display:inline-block; }
  </style>
</head>
<body>
  <div class="demo-shell">
    <p>Blueprint-Auswahl:</p>
    <div class="demo-buttons">
      <button class="demo-button is-active" data-blueprint="header">Header</button>
      <button class="demo-button" data-blueprint="main">Main</button>
      <button class="demo-button" data-blueprint="footer">Footer</button>
    </div>
    <div class="demo-output">
      <h4>Header-Dach aktiv</h4>
      <p>Navigation, Logo und Story-Intro wohnen hier.</p>
      <code>&lt;header&gt;...&lt;/header&gt;</code>
    </div>
  </div>
  <script>
    const demoData = {
      header: { title: 'Header-Dach aktiv', text: 'Navigation, Logo und Story-Intro wohnen hier.', code: '<header>...</header>' },
      main: { title: 'Main-Fluss aktiv', text: 'Hero, Blueprints und Button-Labor sitzen im Main.', code: '<main>...</main>' },
      footer: { title: 'Footer-Signal', text: 'Kontakt + Accessibility-Hinweis geben Wärme.', code: '<footer>...</footer>' }
    };
    const buttons = document.querySelectorAll('.demo-button');
    const output = document.querySelector('.demo-output');
    const title = output.querySelector('h4');
    const text = output.querySelector('p');
    const code = output.querySelector('code');
    buttons.forEach((btn) => {
      btn.addEventListener('click', () => {
        buttons.forEach((button) => button.classList.remove('is-active'));
        btn.classList.add('is-active');
        const info = demoData[btn.dataset.blueprint];
        title.textContent = info.title;
        text.textContent = info.text;
        code.textContent = info.code;
      });
    });
  </script>
</body>
</html>
"""

display(HTML(demo_html))
# Out:
# <!DOCTYPE html>
# <html lang="de">
# <head>
#   <style>
#     body { font-family: 'Inter', sans-serif; background:#020617; color:#f8fbff; }
#     .demo-shell { max-width: 620px; margin: 0 auto; padding: 24px; border-radius: 24px; background: rgba(255,255,255,0.04); border:1px solid rgba(91,250,222,0.4); }
#     .demo-buttons { display:flex; gap:12px; flex-wrap:wrap; }
#     .demo-button { flex:1 1 160px; border:none; border-radius:999px; padding:12px 18px; font-weight:700; text-transform:uppercase; color:#020617; background:linear-gradient(135deg,#5bfade,#7bdff2); box-shadow:0 6px 0 rgba(11,61,99,0.9); cursor:pointer; transition:transform .2s, box-shadow .2s; }
#     .demo-button.is-active { background:linear-gradient(135deg,#8b5cf6,#5bfade); color:#fff; }
#     .demo-button:active { transform:translateY(3px); box-shadow:0 3px 0 rgba(11,61,99,0.9); }
# ...

# %% [markdown]
# # 🚀 Deine Aufgabe: Frost-Timeline vollenden

# %% [markdown]
# ## 🎯 Mission: 3 magische TODOs lösen
# Im Ordner `Aufgabe/` wartet eine fast fertige Version. Ergänze drei Stellen, damit sie mit `Loesung/` mithalten kann. Lies jede Aufgabe laut und hake sie nach dem Testen ab.

# %% [markdown]
# ### 📝 **TODO 1: HTML – Timeline ergänzen**
# **Datei:** `Aufgabe/index.html` (Zeile ~100)
#
# Füge die drei Schritte ein, die in der Lösung nach dem Blueprint-Grid stehen. Nutze kurze Sätze wie "Fundament gießen" oder "Layout formen", damit Kinder sofort verstehen, was passiert.
#
# ```html
# <!-- TODO 1: ... -->
# <div class="timeline">
#   <div class="timeline-step">...</div>
#   ...
# </div>
# ```
#
# So visualisierst du verständlich Fundament → Layout → Buttons.

# %% [markdown]
# ### 🎨 **TODO 2: CSS – 3D-Frost-Effekt aktivieren**
# **Datei:** `Aufgabe/style.css` (Zeile ~130)
#
# Im Kommentar steht, dass Verlauf und Schatten fehlen. Kopiere den sanften Farbverlauf aus `Loesung/style.css`, ergänze einen deutlichen Hover- und Active-Zustand und erkläre im Code-Kommentar kurz, dass der Button dadurch wie ein leuchtender Eisblock wirkt.

# %% [markdown]
# ### ⚡ **TODO 3: JavaScript – Blueprint aktualisieren**
# **Datei:** `Aufgabe/script.js` (Zeile ~25)
#
# Schreibe in `updateOutput` die drei Zeilen, die Titel, Beschreibung und Code setzen, und triggert danach den kurzen Flash-Effekt. Nur so sehen Kinder sofort, dass ihr Klick neuen Inhalt gezaubert hat.

# %% [markdown]
# ## 🏆 Erfolgskontrolle
# - Die Timeline springt bei jedem Klick sauber zum nächsten Schritt und endet sichtbar mit `Fertig!`.
# - Buttons im Labor wechseln Farbe **und** Text, sodass auch ohne Lesen klar ist, welcher aktiv ist.
# - Das Status-Badge taucht nach einem Klick freundlich animiert auf.
# - Header, Main und Footer behalten gleiche Abstände, damit alles ruhig wirkt.

# %% [markdown]
# ## 🌐 Testen deiner Lösung
# - Aufgabe öffnen: https://web.tb-cloudlab.org/2025_Adventskalender/Tag_05/Aufgabe/
# - Lösung vergleichen: https://web.tb-cloudlab.org/2025_Adventskalender/Tag_05/Loesung/
#
# Nutze unbedingt diese Server-URLs, damit Tailwind-CDN und Pfade stimmen, und teste am besten in einem Kinder-freundlichen Browser-Zoom (125 %).

# %% [markdown]
# # 🌟 Erfolg & Möglichkeiten

# %% [markdown]
# - Schiebe weitere Story-Sektionen in neue `section`-Blöcke und gib ihnen klare Überschriften.
# - Tausche die Timeline-Phrasen gegen eigene Bauabschnitte mit kindgerechten Verben.
# - Spiele mit `aria-pressed` oder `aria-live`, um Accessibility weiter auszubauen und Feedback hörbar zu machen.
# - Erstelle eigene Frost-Buttons, die Anime.css-Klassen nutzen und eine kurze Bewegungsstory erzählen.
