# %% [markdown]
# # 📚 Das lernst du heute
#
# ## 🎯 HTML - Die Grundbausteine des Webs
#
# HTML ist wie **Minecraft-Blöcke für Webseiten!** 🧱 Jeder Block hat eine Funktion:
#
# ### 🏗️ Die wichtigsten HTML-Elemente:
#
# **`<h1>` - Der Haupttitel** 📜
# ```html
# <h1>🎄 MINECRAFT WEIHNACHTSDORF 🎄</h1>
# ```
# Wie ein großes **Schild** in Minecraft - jeder sieht es sofort!
#
# **`<p>` - Textblöcke** 📝
# ```html
# <p>Du bist im verschneiten Minecraft-Weihnachtsdorf angekommen!</p>
# ```
# Wie **Bücher** in Minecraft - enthalten die Geschichte!
#
# **`<img>` - Bilder einbinden** 🖼️
# ```html
# <img src="schneeflocke.png" alt="Schneeflocke">
# ```
# Wie **Item Frames** - zeigen coole Bilder!
#
# ### 🌐 Externe Ressourcen - Wie Mods für Minecraft!
#
# **Google Fonts** (Minecraft-Schrift):
# ```html
# <link href="https://fonts.googleapis.com/css2?family=Orbitron" rel="stylesheet">
# ```
#
# **TailwindCSS** (Styling-Power):
# ```html
# <script src="https://cdn.tailwindcss.com"></script>
# ```
#
# ## 🎨 Dein praktisches WOW-Ziel heute:
#
# ✅ **Winter-Farbverlauf** - Von tiefblau zu lila wie ein Minecraft-Himmel
# ✅ **Große Minecraft-Schrift** - Pixelig und retro wie im Spiel
# ✅ **Sanfte Schneeflocken** - Die vom Himmel fallen und sich drehen
# ✅ **Interaktiver Button** - Der auf Klicks reagiert
#
# **Das Ergebnis:** Eine lebendige Webseite, die aussieht wie aus Minecraft! 🎮✨

# %% [markdown]
# # 🧪 Verstehen
#
# ## 🔍 HTML-Struktur verstehen
#
# Jede Webseite ist wie ein **Minecraft-Haus** aufgebaut:
#
# ```html
# <!DOCTYPE html>     <!-- Bauplan-Typ: "Moderne Webseite" -->
# <html>             <!-- Das ganze Haus -->
#   <head>           <!-- Unsichtbare Technik (wie Redstone) -->
#     <title>...</title>  <!-- Name des Hauses -->
#   </head>
#   <body>           <!-- Sichtbarer Bereich (die Räume) -->
#     <h1>...</h1>   <!-- Großes Schild am Eingang -->
#     <p>...</p>     <!-- Möbel und Dekoration -->
#   </body>
# </html>
# ```
#
# ## 🎨 CSS-Klassen - Wie Texture Packs!
#
# CSS-Klassen sind wie **Texture Packs** in Minecraft - sie ändern das Aussehen:
#
# ```css
# .minecraft-title {
#     font-family: 'Orbitron';  /* Pixelige Minecraft-Schrift */
#     color: gold;              /* Goldene Farbe wie Goldblöcke */
#     text-shadow: 4px 4px 0px orange; /* 3D-Schatten-Effekt */
# }
# ```
#
# ## ⚡ JavaScript - Redstone für Webseiten!
#
# JavaScript macht Webseiten **interaktiv**, wie Redstone-Schaltungen:
#
# ```javascript
# // Wenn Button geklickt wird → Aktion ausführen
# button.addEventListener('click', function() {
#     console.log('🚀 Abenteuer gestartet!');
# });
# ```

# %% [markdown]
# # 🧪 Ausprobieren
#
# Führe die folgende Zelle aus. Klicke dafür in den grauen Codeblock und drücke gleichzeitig Shift + Enter.

# %%
from IPython.core.display import HTML
display(HTML("""
<!DOCTYPE html>
<html>
  <head>
    <title>Title</title>

    <!-- 🎨 Einfaches CSS -->
    <style>
      body {
        font-family: Arial, sans-serif;
        background: #fafafa;
        padding: 20px;
      }
      .minecraft-title {
        font-family: 'Orbitron', sans-serif;
        color: gold;
        text-shadow: 4px 4px 0px orange;
      }
      button {
        padding: 10px 20px;
        font-size: 16px;
        cursor: pointer;
      }
    </style>

    <!-- ⚡ Einfaches JavaScript -->
    <script>
      function sayHello() {
        console.log("🚀 Abenteuer gestartet!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");
        alert("Button wurde geklickt!");

      }
    </script>

  </head>

  <body>
    <h1 class="minecraft-title">MINECRAFT</h1>
    <p>🐘💭😶‍🌫️</p>

    <button onclick="sayHello()">Klick mich!</button>
  </body>
</html>
"""))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>Title</title>
#
#     <!-- 🎨 Einfaches CSS -->
#     <style>
#       body {
#         font-family: Arial, sans-serif;
#         background: #fafafa;
#         padding: 20px;
#       }
#       .minecraft-title {
#         font-family: 'Orbitron', sans-serif;
#         color: gold;
#         text-shadow: 4px 4px 0px orange;
#       }
#       button {
#         padding: 10px 20px;
#         font-size: 16px;
#         cursor: pointer;
#       }
#     </style>
#
#     <!-- ⚡ Einfaches JavaScript -->
#     <script>
#       function sayHello() {
#         console.log("🚀 Abenteuer gestartet!");
#         alert("Button wurde geklickt!");
#         alert("Button wurde geklickt!");
#         alert("Button wurde geklickt!");
#       }
#     </script>
#
#   </head>
#
#   <body>
#     <h1 class="minecraft-title">MINECRAFT</h1>
#     <p>🐘💭😶‍🌫️</p>
#
#     <button onclick="sayHello()">Klick mich!</button>
#   </body>
# </html>

# %% [markdown]
# # 🚀 Deine Aufgabe: Den Kristall zum Leben erwecken!
#
# ## 🎯 Mission: 3 magische TODOs lösen
#
# In deinem `Tag_01/Aufgabe/` Verzeichnis wartet eine **fast fertige Webseite** auf dich! Du musst nur **3 kleine Zauber** vervollständigen:
#
# ### 📝 **TODO 1: HTML - Der fehlende Haupttitel**
# **Datei:** `index.html` (Zeile ~35)
#
# **Was zu tun ist:**
# ```html
# <!-- TODO 1: Füge hier den Haupttitel h1 mit der CSS-Klasse "minecraft-title" hinzu -->
# <!-- Der Titel soll "🎄 MINECRAFT 🎄" enthalten -->
# ```
#
# **Lösung:** Erstelle ein `<h1>`-Element mit:
# - CSS-Klasse: `minecraft-title`
# - TailwindCSS-Klassen: `text-6xl md:text-8xl font-black text-yellow-400 mb-4 drop-shadow-lg`
# - Inhalt: `🎄 MINECRAFT 🎄`
#
# ### 🎨 **TODO 2: CSS - Minecraft-Titel-Styling aktivieren**
# **Datei:** `style.css` (Zeile ~6-20)
#
# **Was zu tun ist:**
# ```css
# /* TODO 2: Aktiviere hier die Minecraft-Schrift für den Titel */
# /* Entferne die Kommentarzeichen (/* und */) um den gesamten Block: */
# ```
#
# **Lösung:** Entferne das `/*` am Anfang und das `*/` am Ende des `.minecraft-title` CSS-Blocks, damit die pixelige Minecraft-Schrift mit Schatten und Animation aktiviert wird.
#
# ### ⚡ **TODO 3: JavaScript - Button-Interaktivität vervollständigen**
# **Datei:** `script.js` (Zeile ~15)
#
# **Was zu tun ist:**
# ```javascript
# // TODO 3: Vervollständige die Abenteuer-Button Funktionalität
# // Lösche die Kommentarzeichen (//) vor der nächsten Zeile:
# // setupAdventureButton();
# ```
#
# **Lösung:** Entferne die `//` vor `setupAdventureButton();`, damit der Button auf Klicks reagiert und seine Farbe von rot zu grün ändert.
#
# ## 🏆 Erfolgskontrolle
#
# **Nach allen TODOs solltest du sehen:**
# ✅ Großer goldener "MINECRAFT" Titel mit 3D-Effekt
# ✅ Fallende Schneeflocken die sich drehen
# ✅ Button der auf Klicks reagiert und die Farbe ändert
# ✅ Willkommensnachricht erscheint nach Button-Klick
#
# ## 🌐 Testen deiner Lösung
#
# **Öffne in deinem Browser:**
#
# https://web.tb-cloudlab.org/2025_Adventskalender/Tag_01/Aufgabe/
#
# **Vergleiche mit der Musterlösung:**
#
# https://web.tb-cloudlab.org/2025_Adventskalender/Tag_01/Loesung/
#
# **⚠️ Wichtig:** Die Dateien funktionieren nur über diese Server-URLs!

# %% [markdown]
# # Weitere Ideen
#
# - Verändere die Seite nach deinen Wünschen
